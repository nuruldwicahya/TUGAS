# %% [markdown]
# <a href="https://colab.research.google.com/github/nuruldwicahya/TUGAS/blob/master/EclatMovie.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Eclat for Movie Recomendation Analysis**

# %% [markdown]
# Menggunakan algoritma Eclat untuk mendapatkan rekomendasi film berdasarkan aktor, sutradara dan genre
#
# Eclat pada dasarnya adalah versi apriori yang disederhanakan, yang hanya mempertimbangkan support, daripada menggunakan ketiganya seperti apriori, yaitu support, Confidence , dan Lift. Oleh karena itu, dapat diimplementasikan dengan cara yang sama seperti apriori, dengan hanya mempertimbangkan Support selama visualisasi

# %%
pip install apyori
# Out:
# Collecting apyori
#   Downloading https://files.pythonhosted.org/packages/5e/62/5ffde5c473ea4b033490617ec5caa80d59804875ad3c3c57c0976533a21a/apyori-1.1.2.tar.gz
# Building wheels for collected packages: apyori
#   Building wheel for apyori (setup.py) ... done
#   Created wheel for apyori: filename=apyori-1.1.2-cp36-none-any.whl size=5975 sha256=59d5c71f354ca42cfbd250502cca3e6c0949cde5f6a6d65a6823dcc5e175a4cc
#   Stored in directory: /root/.cache/pip/wheels/5d/92/bb/474bbadbc8c0062b9eb168f69982a0443263f8ab1711a8cad0
# Successfully built apyori
# Installing collected packages: apyori
# Successfully installed apyori-1.1.2

# %%
import pandas as pd
import numpy as np
from apyori import apriori
import random

# %% [markdown]
# ## Preprocessing the data

# %%
url = 'https://raw.githubusercontent.com/furqoncreative/data-mining-eclat/master/movie_metadata.csv'
dataset=pd.read_csv(url)
dataset.fillna(value=0,axis=1,inplace=True)
dataset.head()
# Out:
#    color      director_name  ...  aspect_ratio  movie_facebook_likes
# 0  Color      James Cameron  ...          1.78                 33000
# 1  Color     Gore Verbinski  ...          2.35                     0
# 2  Color         Sam Mendes  ...          2.35                 85000
# 3  Color  Christopher Nolan  ...          2.35                164000
# 4      0        Doug Walker  ...          0.00                     0
#
# [5 rows x 28 columns]

# %% [markdown]
# Menampung dataset dalam bentuk array

# %%
dataset.shape
# Out:
# (5043, 28)

# %%
movieData=[]
for i in range(0,1000):
    movieData.append([str(dataset.values[i,j]) for j in range(0,28)])

# %%
movieData[:1]
# Out:
# [['Color',
#   'James Cameron',
#   '723.0',
#   '178.0',
#   '0.0',
#   '855.0',
#   'Joel David Moore',
#   '1000.0',
#   '760505847.0',
#   'Action|Adventure|Fantasy|Sci-Fi',
#   'CCH Pounder',
#   'Avatar\xa0',
#   '886204',
#   '4834',
#   'Wes Studi',
#   '0.0',
#   'avatar|future|marine|native|paraplegic',
#   'http://www.imdb.com/title/tt0499549/?ref_=fn_tt_tt_1',
#   '3054.0',
#   'English',
#   'USA',
#   'PG-13',
#   '237000000.0',
#   '2009.0',
#   '936.0',
#   '7.9',
#   '1.78',
#   '33000']]

# %% [markdown]
# Membuat sampel transaksi kebiasan user menonton film dalam 30 hari.
# Dengan asumsi bahwa film yang ditonton selanjutnya:
# 1. memiliki aktor yang sama dari film sebelumnya, atau
# 2. memiliki sutradara yang sama dari film sebelumnya, atau
# 3. memiliki genre yang sama dari film sebelumnya

# %%
def getNextMovie(s):
    for i in range(0,1000):
      if (movieData)[i][10] == s[10] or (movieData)[i][9] == s[1] or (movieData)[i][9] == s[9]:
        if movieData[i][11] != s[11]:
          return movieData[i]
        else:
          return random.choice(movieData)
      else:
        return random.choice(movieData)

# %%
movieTransactions=[]
userTransactions=[]
for i in range(0,1000):
    firtsMovie = (random.choice(movieData))
    userTransactions.append([])
    movieTransactions.append([])
    movieTransactions[i].append(getNextMovie(firtsMovie))
    for j in range(0,30):
      movieTransactions[i].append(getNextMovie(movieTransactions[i][j]))
      userTransactions[i].append(movieTransactions[i][j][11].replace(u'\xa0', u''))

# %%
userTransactions[:3]
# Out:
# [['The Other Guys',
#   'I Am Legend',
#   'The Hobbit: The Battle of the Five Armies',
#   'Resident Evil: Apocalypse',
#   'Funny People',
#   'Brave',
#   'Sin City: A Dame to Kill For',
#   'Doom',
#   'Antz',
#   'Space Jam',
#   "Charlie's Angels",
#   'In the Heart of the Sea',
#   'The Godfather: Part III',
#   'Bee Movie',
#   'Body of Lies',
#   'Annie',
#   'Looney Tunes: Back in Action',
#   'Despicable Me 2',
#   'Step Brothers',
#   'Valkyrie',
#   'Ben-Hur',
#   'Road to Perdition',
#   'Total Recall',
#   "Captain Corelli's Mandolin",
#   'Mars Needs Moms',
#   'Dr. Dolittle 2',
#   'Rio 2',
#   'Runaway Bride',
#   'Thor',
#   'Duplicity'],
#  ['Knight and Day',
#   'Oceans',
#   'Firewall',
#   'Rise of the Guardians',
#   'Terminator Genisys',
#   'Lucky You',
#   'Monsters, Inc.',
#   'Failure to Launch',
#   '2 Fast 2 Furious',
#   'The Hobbit: An Unexpected Journey',
#   'Fun with Dick and Jane',
#   'Casino',
#   'Grindhouse',
#   'Me, Myself & Irene',
#   'Paycheck',
#   'Jack Ryan: Shadow Recruit',
#   'Red Planet',
#   'Soldier',
#   'DragonHeart',
#   'Dreamgirls',
#   'Tango & Cash',
#   'The Cat in the Hat',
#   "Pirates of the Caribbean: At World's End",
#   'San Andreas',
#   'Stargate SG-1',
#   'Just Go with It',
#   'Cast Away',
#   'Tropic Thunder',
#   'Alvin and the Chipmunks: The Road Chip',
#   'Pocahontas'],
#  ['Hannibal',
#   'Eyes Wide Shut',
#   'Swordfish',
#   'A Good Day to Die Hard',
#   'The Break-Up',
#   'The World Is Not Enough',
#   'The Shaggy Dog',
#   'Total Recall',
#   'Shrek',
#   'Two Weeks Notice',
#   'Garfield',
#   'Epic',
#   "Harry Potter and the Sorcerer's Stone",
#   'The Pirates! Band of Misfits',
#   'Supernova',
#   'The Croods',
#   'The Nutcracker in 3D',
#   'Mars Attacks!',
#   'Star Wars: Episode III - Revenge of the Sith',
#   'Avatar',
#   'Random Hearts',
#   'Inkheart',
#   'Blade II',
#   'The Cat in the Hat',
#   'A Very Long Engagement',
#   'The Secret Life of Walter Mitty',
#   'A Very Long Engagement',
#   'Rollerball',
#   'Divergent',
#   'G.I. Joe: Retaliation']]

# %% [markdown]
# ## Training the Eclat model

# %%
# min_support = film ditonton 1x sehari * 30 hari / 1000 user = 0.003

from apyori import apriori
rules=apriori(userTransactions,min_support=0.003,min_confidence=0.2,min_lift=3,min_length=3,max_length=3)

# %% [markdown]
# List hasil data training:

# %%
results=list(rules)
results
# Out:
# [RelationRecord(items=frozenset({'13 Hours', 'Now You See Me 2'}), support=0.006, ordered_statistics=[OrderedStatistic(items_base=frozenset({'13 Hours'}), items_add=frozenset({'Now You See Me 2'}), confidence=0.2, lift=6.0606060606060606)]),
#  RelationRecord(items=frozenset({'13 Hours', 'S.W.A.T.'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'S.W.A.T.'}), items_add=frozenset({'13 Hours'}), confidence=0.20833333333333334, lift=6.944444444444445)]),
#  RelationRecord(items=frozenset({'The SpongeBob Movie: Sponge Out of Water', '2 Guns'}), support=0.007, ordered_statistics=[OrderedStatistic(items_base=frozenset({'2 Guns'}), items_add=frozenset({'The SpongeBob Movie: Sponge Out of Water'}), confidence=0.25, lift=5.1020408163265305)]),
#  RelationRecord(items=frozenset({'50 First Dates', 'Catwoman'}), support=0.006, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Catwoman'}), items_add=frozenset({'50 First Dates'}), confidence=0.24, lift=5.454545454545455)]),
#  RelationRecord(items=frozenset({'50 First Dates', 'Salt'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Salt'}), items_add=frozenset({'50 First Dates'}), confidence=0.2105263157894737, lift=4.784688995215312)]),
#  RelationRecord(items=frozenset({'A Civil Action', 'WALL·E'}), support=0.008, ordered_statistics=[OrderedStatistic(items_base=frozenset({'WALL·E'}), items_add=frozenset({'A Civil Action'}), confidence=0.21621621621621623, lift=5.02828409805154)]),
#  RelationRecord(items=frozenset({'A Good Day to Die Hard', 'Star Wars: Episode III - Revenge of the Sith'}), support=0.007, ordered_statistics=[OrderedStatistic(items_base=frozenset({'A Good Day to Die Hard'}), items_add=frozenset({'Star Wars: Episode III - Revenge of the Sith'}), confidence=0.23333333333333334, lift=4.861111111111111)]),
#  RelationRecord(items=frozenset({'Mission: Impossible', 'A.I. Artificial Intelligence'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Mission: Impossible'}), items_add=frozenset({'A.I. Artificial Intelligence'}), confidence=0.2, lift=6.666666666666667)]),
#  RelationRecord(items=frozenset({'Absolute Power', 'White House Down'}), support=0.006, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Absolute Power'}), items_add=frozenset({'White House Down'}), confidence=0.2, lift=5.0)]),
#  RelationRecord(items=frozenset({'After Earth', 'Dinosaur'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'After Earth'}), items_add=frozenset({'Dinosaur'}), confidence=0.2173913043478261, lift=6.3938618925831205)]),
#  RelationRecord(items=frozenset({'After Earth', 'Total Recall'}), support=0.006, ordered_statistics=[OrderedStatistic(items_base=frozenset({'After Earth'}), items_add=frozenset({'Total Recall'}), confidence=0.2608695652173913, lift=4.576659038901601)]),
#  RelationRecord(items=frozenset({'Air Force One', 'We Are Marshall'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Air Force One'}), items_add=frozenset({'We Are Marshall'}), confidence=0.22222222222222224, lift=5.847953216374269)]),
#  RelationRecord(items=frozenset({'The Thin Red Line', 'Alice Through the Looking Glass'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'The Thin Red Line'}), items_add=frozenset({'Alice Through the Looking Glass'}), confidence=0.22222222222222224, lift=6.349206349206349)]),
#  RelationRecord(items=frozenset({'Allegiant', 'Men in Black 3'}), support=0.006, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Allegiant'}), items_add=frozenset({'Men in Black 3'}), confidence=0.21428571428571427, lift=6.493506493506493)]),
#  RelationRecord(items=frozenset({'The Chronicles of Riddick', 'Almost Famous'}), support=0.006, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Almost Famous'}), items_add=frozenset({'The Chronicles of Riddick'}), confidence=0.21428571428571427, lift=5.9523809523809526)]),
#  RelationRecord(items=frozenset({'The Patriot', 'Alvin and the Chipmunks'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'The Patriot'}), items_add=frozenset({'Alvin and the Chipmunks'}), confidence=0.2105263157894737, lift=7.518796992481203)]),
#  RelationRecord(items=frozenset({'Perfume: The Story of a Murderer', 'Anger Management'}), support=0.006, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Perfume: The Story of a Murderer'}), items_add=frozenset({'Anger Management'}), confidence=0.2, lift=5.88235294117647)]),
#  RelationRecord(items=frozenset({'Armageddon', "Dante's Peak"}), support=0.006, ordered_statistics=[OrderedStatistic(items_base=frozenset({"Dante's Peak"}), items_add=frozenset({'Armageddon'}), confidence=0.23076923076923078, lift=5.628517823639775)]),
#  RelationRecord(items=frozenset({'Armageddon', 'Red Planet'}), support=0.006, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Red Planet'}), items_add=frozenset({'Armageddon'}), confidence=0.25, lift=6.097560975609756)]),
#  RelationRecord(items=frozenset({'Armageddon', 'Rise of the Planet of the Apes'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Rise of the Planet of the Apes'}), items_add=frozenset({'Armageddon'}), confidence=0.20833333333333334, lift=5.08130081300813)]),
#  RelationRecord(items=frozenset({'Around the World in 80 Days', 'Resident Evil: Retribution'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Around the World in 80 Days'}), items_add=frozenset({'Resident Evil: Retribution'}), confidence=0.20833333333333334, lift=5.787037037037038)]),
#  RelationRecord(items=frozenset({'Asterix at the Olympic Games', 'Tangled'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Asterix at the Olympic Games'}), items_add=frozenset({'Tangled'}), confidence=0.2173913043478261, lift=8.695652173913043)]),
#  RelationRecord(items=frozenset({'End of Days', 'Avatar'}), support=0.025, ordered_statistics=[OrderedStatistic(items_base=frozenset({'End of Days'}), items_add=frozenset({'Avatar'}), confidence=1.0, lift=5.025125628140703)]),
#  RelationRecord(items=frozenset({'Man of Steel', 'Avatar'}), support=0.028, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Man of Steel'}), items_add=frozenset({'Avatar'}), confidence=1.0, lift=5.025125628140703)]),
#  RelationRecord(items=frozenset({'Star Wars: Episode I - The Phantom Menace', 'Avatar'}), support=0.017, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Star Wars: Episode I - The Phantom Menace'}), items_add=frozenset({'Avatar'}), confidence=1.0, lift=5.025125628140703)]),
#  RelationRecord(items=frozenset({'Star Wars: Episode II - Attack of the Clones', 'Avatar'}), support=0.028, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Star Wars: Episode II - Attack of the Clones'}), items_add=frozenset({'Avatar'}), confidence=1.0, lift=5.025125628140703)]),
#  RelationRecord(items=frozenset({'Avatar', 'Star Wars: Episode III - Revenge of the Sith'}), support=0.047, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Avatar'}), items_add=frozenset({'Star Wars: Episode III - Revenge of the Sith'}), confidence=0.23618090452261306, lift=4.920435510887772), OrderedStatistic(items_base=frozenset({'Star Wars: Episode III - Revenge of the Sith'}), items_add=frozenset({'Avatar'}), confidence=0.9791666666666666, lift=4.9204355108877715)]),
#  RelationRecord(items=frozenset({'The Amazing Spider-Man 2', 'Avatar'}), support=0.019, ordered_statistics=[OrderedStatistic(items_base=frozenset({'The Amazing Spider-Man 2'}), items_add=frozenset({'Avatar'}), confidence=0.8636363636363636, lift=4.339881224303335)]),
#  RelationRecord(items=frozenset({'The League of Extraordinary Gentlemen', 'Avatar'}), support=0.023, ordered_statistics=[OrderedStatistic(items_base=frozenset({'The League of Extraordinary Gentlemen'}), items_add=frozenset({'Avatar'}), confidence=1.0, lift=5.025125628140703)]),
#  RelationRecord(items=frozenset({'The Da Vinci Code', 'Babe: Pig in the City'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Babe: Pig in the City'}), items_add=frozenset({'The Da Vinci Code'}), confidence=0.20833333333333334, lift=5.787037037037038)]),
#  RelationRecord(items=frozenset({'The Invasion', 'Bad Boys II'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Bad Boys II'}), items_add=frozenset({'The Invasion'}), confidence=0.22222222222222224, lift=6.944444444444445)]),
#  RelationRecord(items=frozenset({'Resident Evil: Retribution', 'Bandits'}), support=0.006, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Bandits'}), items_add=frozenset({'Resident Evil: Retribution'}), confidence=0.23076923076923078, lift=6.4102564102564115)]),
#  RelationRecord(items=frozenset({'Battlefield Earth', 'Land of the Lost'}), support=0.006, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Battlefield Earth'}), items_add=frozenset({'Land of the Lost'}), confidence=0.2, lift=5.0)]),
#  RelationRecord(items=frozenset({'Captain America: Civil War', 'Be Cool'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Captain America: Civil War'}), items_add=frozenset({'Be Cool'}), confidence=0.2105263157894737, lift=4.895960832313342)]),
#  RelationRecord(items=frozenset({'Cats & Dogs', 'Be Cool'}), support=0.006, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Cats & Dogs'}), items_add=frozenset({'Be Cool'}), confidence=0.20689655172413793, lift=4.811547714514836)]),
#  RelationRecord(items=frozenset({'Ben-Hur', 'Godzilla Resurgence'}), support=0.006, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Ben-Hur'}), items_add=frozenset({'Godzilla Resurgence'}), confidence=0.24, lift=3.428571428571428)]),
#  RelationRecord(items=frozenset({'Bewitched', 'The Thin Red Line'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'The Thin Red Line'}), items_add=frozenset({'Bewitched'}), confidence=0.22222222222222224, lift=5.847953216374269)]),
#  RelationRecord(items=frozenset({'Gravity', 'Bicentennial Man'}), support=0.006, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Bicentennial Man'}), items_add=frozenset({'Gravity'}), confidence=0.20689655172413793, lift=5.44464609800363)]),
#  RelationRecord(items=frozenset({'Harry Potter and the Goblet of Fire', 'Big Fish'}), support=0.007, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Harry Potter and the Goblet of Fire'}), items_add=frozenset({'Big Fish'}), confidence=0.31818181818181823, lift=7.575757575757576)]),
#  RelationRecord(items=frozenset({'The Spanish Prisoner', 'Big Fish'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'The Spanish Prisoner'}), items_add=frozenset({'Big Fish'}), confidence=0.2, lift=4.761904761904762)]),
#  RelationRecord(items=frozenset({'Black Mass', 'Thunderbirds'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Thunderbirds'}), items_add=frozenset({'Black Mass'}), confidence=0.2173913043478261, lift=6.793478260869565)]),
#  RelationRecord(items=frozenset({'xXx', 'Blade: Trinity'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Blade: Trinity'}), items_add=frozenset({'xXx'}), confidence=0.2173913043478261, lift=7.012622720897617)]),
#  RelationRecord(items=frozenset({'The Postman', 'Blood Diamond'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Blood Diamond'}), items_add=frozenset({'The Postman'}), confidence=0.20833333333333334, lift=7.71604938271605)]),
#  RelationRecord(items=frozenset({'The Bourne Ultimatum', 'Brave'}), support=0.007, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Brave'}), items_add=frozenset({'The Bourne Ultimatum'}), confidence=0.21212121212121213, lift=8.484848484848484), OrderedStatistic(items_base=frozenset({'The Bourne Ultimatum'}), items_add=frozenset({'Brave'}), confidence=0.27999999999999997, lift=8.484848484848484)]),
#  RelationRecord(items=frozenset({'The Love Guru', 'Bridget Jones: The Edge of Reason'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'The Love Guru'}), items_add=frozenset({'Bridget Jones: The Edge of Reason'}), confidence=0.20833333333333334, lift=7.71604938271605)]),
#  RelationRecord(items=frozenset({'The Prince of Egypt', 'Bruce Almighty'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Bruce Almighty'}), items_add=frozenset({'The Prince of Egypt'}), confidence=0.2, lift=5.555555555555556)]),
#  RelationRecord(items=frozenset({'Green Lantern', 'Bulletproof Monk'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Bulletproof Monk'}), items_add=frozenset({'Green Lantern'}), confidence=0.20833333333333334, lift=7.71604938271605)]),
#  RelationRecord(items=frozenset({'Oliver Twist', 'Captain America: Civil War'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Captain America: Civil War'}), items_add=frozenset({'Oliver Twist'}), confidence=0.2105263157894737, lift=6.791171477079796)]),
#  RelationRecord(items=frozenset({'Captain America: Civil War', 'Pan'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Captain America: Civil War'}), items_add=frozenset({'Pan'}), confidence=0.2105263157894737, lift=3.5682426404995544)]),
#  RelationRecord(items=frozenset({'Captain America: The First Avenger', 'Forrest Gump'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Captain America: The First Avenger'}), items_add=frozenset({'Forrest Gump'}), confidence=0.2173913043478261, lift=6.03864734299517)]),
#  RelationRecord(items=frozenset({'The Bourne Identity', 'Captain America: The Winter Soldier'}), support=0.006, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Captain America: The Winter Soldier'}), items_add=frozenset({'The Bourne Identity'}), confidence=0.25, lift=7.575757575757575)]),
#  RelationRecord(items=frozenset({'The Spirit', 'Cast Away'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'The Spirit'}), items_add=frozenset({'Cast Away'}), confidence=0.2272727272727273, lift=5.1652892561983474)]),
#  RelationRecord(items=frozenset({'Cats & Dogs: The Revenge of Kitty Galore', 'Race to Witch Mountain'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Race to Witch Mountain'}), items_add=frozenset({'Cats & Dogs: The Revenge of Kitty Galore'}), confidence=0.2, lift=7.142857142857143)]),
#  RelationRecord(items=frozenset({'Central Intelligence', 'Pan'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Central Intelligence'}), items_add=frozenset({'Pan'}), confidence=0.2173913043478261, lift=3.684598378776714)]),
#  RelationRecord(items=frozenset({'Charlie and the Chocolate Factory', 'Star Trek'}), support=0.006, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Charlie and the Chocolate Factory'}), items_add=frozenset({'Star Trek'}), confidence=0.20689655172413793, lift=6.269592476489028)]),
#  RelationRecord(items=frozenset({"Charlie's Angels", 'Resident Evil: Apocalypse'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Resident Evil: Apocalypse'}), items_add=frozenset({"Charlie's Angels"}), confidence=0.20833333333333334, lift=6.313131313131313)]),
#  RelationRecord(items=frozenset({'Over the Hedge', "Charlie's Angels: Full Throttle"}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Over the Hedge'}), items_add=frozenset({"Charlie's Angels: Full Throttle"}), confidence=0.20833333333333334, lift=5.787037037037038)]),
#  RelationRecord(items=frozenset({'City of Angels', 'Total Recall'}), support=0.006, ordered_statistics=[OrderedStatistic(items_base=frozenset({'City of Angels'}), items_add=frozenset({'Total Recall'}), confidence=0.21428571428571427, lift=3.759398496240601)]),
#  RelationRecord(items=frozenset({'Clear and Present Danger', 'The Lord of the Rings: The Fellowship of the Ring'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'The Lord of the Rings: The Fellowship of the Ring'}), items_add=frozenset({'Clear and Present Danger'}), confidence=0.2105263157894737, lift=5.54016620498615)]),
#  RelationRecord(items=frozenset({'Cloudy with a Chance of Meatballs 2', 'Nine'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Cloudy with a Chance of Meatballs 2'}), items_add=frozenset({'Nine'}), confidence=0.2, lift=6.8965517241379315)]),
#  RelationRecord(items=frozenset({'Cloudy with a Chance of Meatballs 2', 'The Expendables'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Cloudy with a Chance of Meatballs 2'}), items_add=frozenset({'The Expendables'}), confidence=0.2, lift=7.142857142857143)]),
#  RelationRecord(items=frozenset({'Cloudy with a Chance of Meatballs 2', 'The Ring Two'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Cloudy with a Chance of Meatballs 2'}), items_add=frozenset({'The Ring Two'}), confidence=0.2, lift=6.0606060606060606)]),
#  RelationRecord(items=frozenset({'Cloudy with a Chance of Meatballs 2', 'We Are Marshall'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Cloudy with a Chance of Meatballs 2'}), items_add=frozenset({'We Are Marshall'}), confidence=0.2, lift=5.2631578947368425)]),
#  RelationRecord(items=frozenset({'Cloudy with a Chance of Meatballs 2', 'X-Men'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Cloudy with a Chance of Meatballs 2'}), items_add=frozenset({'X-Men'}), confidence=0.2, lift=5.88235294117647)]),
#  RelationRecord(items=frozenset({'Collateral', 'Pan'}), support=0.006, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Collateral'}), items_add=frozenset({'Pan'}), confidence=0.24, lift=4.067796610169491)]),
#  RelationRecord(items=frozenset({'The Avengers', 'Crazy, Stupid, Love.'}), support=0.006, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Crazy, Stupid, Love.'}), items_add=frozenset({'The Avengers'}), confidence=0.21428571428571427, lift=3.6319612590799033)]),
#  RelationRecord(items=frozenset({'Godzilla Resurgence', 'Creepshow'}), support=0.006, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Creepshow'}), items_add=frozenset({'Godzilla Resurgence'}), confidence=0.25, lift=3.571428571428571)]),
#  RelationRecord(items=frozenset({'Cutthroat Island', 'The Flintstones in Viva Rock Vegas'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'The Flintstones in Viva Rock Vegas'}), items_add=frozenset({'Cutthroat Island'}), confidence=0.2, lift=5.2631578947368425)]),
#  RelationRecord(items=frozenset({"Daddy's Home", 'Yogi Bear'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Yogi Bear'}), items_add=frozenset({"Daddy's Home"}), confidence=0.2105263157894737, lift=6.791171477079796)]),
#  RelationRecord(items=frozenset({'G.I. Joe: The Rise of Cobra', 'Deadpool'}), support=0.006, ordered_statistics=[OrderedStatistic(items_base=frozenset({'G.I. Joe: The Rise of Cobra'}), items_add=frozenset({'Deadpool'}), confidence=0.21428571428571427, lift=6.912442396313364)]),
#  RelationRecord(items=frozenset({'The Flintstones in Viva Rock Vegas', 'Death Becomes Her'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'The Flintstones in Viva Rock Vegas'}), items_add=frozenset({'Death Becomes Her'}), confidence=0.2, lift=6.0606060606060606)]),
#  RelationRecord(items=frozenset({'Deep Blue Sea', 'Hercules'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Deep Blue Sea'}), items_add=frozenset({'Hercules'}), confidence=0.20833333333333334, lift=3.2552083333333335)]),
#  RelationRecord(items=frozenset({'The Chronicles of Riddick', 'Deep Blue Sea'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Deep Blue Sea'}), items_add=frozenset({'The Chronicles of Riddick'}), confidence=0.20833333333333334, lift=5.787037037037038)]),
#  RelationRecord(items=frozenset({'Despicable Me', 'Race to Witch Mountain'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Race to Witch Mountain'}), items_add=frozenset({'Despicable Me'}), confidence=0.2, lift=6.8965517241379315)]),
#  RelationRecord(items=frozenset({'Snow White and the Huntsman', 'Die Another Day'}), support=0.006, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Die Another Day'}), items_add=frozenset({'Snow White and the Huntsman'}), confidence=0.2, lift=3.3898305084745766)]),
#  RelationRecord(items=frozenset({'Poseidon', 'Dinner for Schmucks'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Poseidon'}), items_add=frozenset({'Dinner for Schmucks'}), confidence=0.25, lift=7.352941176470588)]),
#  RelationRecord(items=frozenset({'Disclosure', 'Monkeybone'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Monkeybone'}), items_add=frozenset({'Disclosure'}), confidence=0.2173913043478261, lift=7.763975155279503)]),
#  RelationRecord(items=frozenset({'Django Unchained', 'Firewall'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Firewall'}), items_add=frozenset({'Django Unchained'}), confidence=0.20833333333333334, lift=8.012820512820513)]),
#  RelationRecord(items=frozenset({'Dreamgirls', 'Scott Pilgrim vs. the World'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Scott Pilgrim vs. the World'}), items_add=frozenset({'Dreamgirls'}), confidence=0.20833333333333334, lift=6.944444444444445)]),
#  RelationRecord(items=frozenset({'Entrapment', 'The Thin Red Line'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'The Thin Red Line'}), items_add=frozenset({'Entrapment'}), confidence=0.22222222222222224, lift=7.407407407407408)]),
#  RelationRecord(items=frozenset({'Escape Plan', 'Hansel & Gretel: Witch Hunters'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Hansel & Gretel: Witch Hunters'}), items_add=frozenset({'Escape Plan'}), confidence=0.2, lift=6.8965517241379315)]),
#  RelationRecord(items=frozenset({'Escape Plan', 'The Simpsons Movie'}), support=0.006, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Escape Plan'}), items_add=frozenset({'The Simpsons Movie'}), confidence=0.20689655172413793, lift=5.44464609800363)]),
#  RelationRecord(items=frozenset({'John Carter', 'Evan Almighty'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'John Carter'}), items_add=frozenset({'Evan Almighty'}), confidence=0.20833333333333334, lift=6.944444444444445)]),
#  RelationRecord(items=frozenset({'Evolution', 'Fantastic Four'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Evolution'}), items_add=frozenset({'Fantastic Four'}), confidence=0.20833333333333334, lift=3.7202380952380953)]),
#  RelationRecord(items=frozenset({'Red Tails', 'Evolution'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Evolution'}), items_add=frozenset({'Red Tails'}), confidence=0.20833333333333334, lift=6.944444444444445)]),
#  RelationRecord(items=frozenset({'The Incredible Hulk', 'Evolution'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Evolution'}), items_add=frozenset({'The Incredible Hulk'}), confidence=0.20833333333333334, lift=7.183908045977011)]),
#  RelationRecord(items=frozenset({'Evolution', 'Total Recall'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Evolution'}), items_add=frozenset({'Total Recall'}), confidence=0.20833333333333334, lift=3.654970760233918)]),
#  RelationRecord(items=frozenset({'The Pirates! Band of Misfits', 'Executive Decision'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'The Pirates! Band of Misfits'}), items_add=frozenset({'Executive Decision'}), confidence=0.23809523809523808, lift=5.952380952380952)]),
#  RelationRecord(items=frozenset({'Interstellar', 'Exodus: Gods and Kings'}), support=0.007, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Exodus: Gods and Kings'}), items_add=frozenset({'Interstellar'}), confidence=0.2692307692307693, lift=9.283819628647215), OrderedStatistic(items_base=frozenset({'Interstellar'}), items_add=frozenset({'Exodus: Gods and Kings'}), confidence=0.24137931034482757, lift=9.283819628647215)]),
#  RelationRecord(items=frozenset({'Failure to Launch', 'Stepmom'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Stepmom'}), items_add=frozenset({'Failure to Launch'}), confidence=0.22222222222222224, lift=9.25925925925926)]),
#  RelationRecord(items=frozenset({'Fantastic Four', 'Stuart Little 2'}), support=0.006, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Stuart Little 2'}), items_add=frozenset({'Fantastic Four'}), confidence=0.22222222222222224, lift=3.9682539682539684)]),
#  RelationRecord(items=frozenset({'Fantastic Four', 'The Expendables'}), support=0.006, ordered_statistics=[OrderedStatistic(items_base=frozenset({'The Expendables'}), items_add=frozenset({'Fantastic Four'}), confidence=0.21428571428571427, lift=3.826530612244898)]),
#  RelationRecord(items=frozenset({"Winter's Tale", 'Fantastic Four'}), support=0.006, ordered_statistics=[OrderedStatistic(items_base=frozenset({"Winter's Tale"}), items_add=frozenset({'Fantastic Four'}), confidence=0.23076923076923078, lift=4.120879120879121)]),
#  RelationRecord(items=frozenset({'Fight Club', 'Focus'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Fight Club'}), items_add=frozenset({'Focus'}), confidence=0.2272727272727273, lift=6.4935064935064934)]),
#  RelationRecord(items=frozenset({'Transformers: Revenge of the Fallen', 'Fight Club'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Fight Club'}), items_add=frozenset({'Transformers: Revenge of the Fallen'}), confidence=0.2272727272727273, lift=6.4935064935064934)]),
#  RelationRecord(items=frozenset({'Finding Nemo', 'Lost in Space'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Lost in Space'}), items_add=frozenset({'Finding Nemo'}), confidence=0.2105263157894737, lift=6.578947368421053)]),
#  RelationRecord(items=frozenset({'Space Cowboys', 'First Knight'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'First Knight'}), items_add=frozenset({'Space Cowboys'}), confidence=0.20833333333333334, lift=6.944444444444445)]),
#  RelationRecord(items=frozenset({'Flubber', 'Iron Man 2'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Flubber'}), items_add=frozenset({'Iron Man 2'}), confidence=0.2173913043478261, lift=6.793478260869565)]),
#  RelationRecord(items=frozenset({'The Chronicles of Narnia: The Lion, the Witch and the Wardrobe', 'Flubber'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Flubber'}), items_add=frozenset({'The Chronicles of Narnia: The Lion, the Witch and the Wardrobe'}), confidence=0.2173913043478261, lift=5.434782608695652)]),
#  RelationRecord(items=frozenset({"Fool's Gold", "It's Complicated"}), support=0.003, ordered_statistics=[OrderedStatistic(items_base=frozenset({"It's Complicated"}), items_add=frozenset({"Fool's Gold"}), confidence=0.3, lift=9.67741935483871)]),
#  RelationRecord(items=frozenset({'For Love of the Game', 'The Flintstones in Viva Rock Vegas'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'The Flintstones in Viva Rock Vegas'}), items_add=frozenset({'For Love of the Game'}), confidence=0.2, lift=5.405405405405406)]),
#  RelationRecord(items=frozenset({'Four Christmases', 'The Twilight Saga: Breaking Dawn - Part 2'}), support=0.007, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Four Christmases'}), items_add=frozenset({'The Twilight Saga: Breaking Dawn - Part 2'}), confidence=0.21212121212121213, lift=3.721424774056353)]),
#  RelationRecord(items=frozenset({'From Paris with Love', 'Hansel & Gretel: Witch Hunters'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Hansel & Gretel: Witch Hunters'}), items_add=frozenset({'From Paris with Love'}), confidence=0.2, lift=7.692307692307693)]),
#  RelationRecord(items=frozenset({'Garfield 2', 'The Beach'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'The Beach'}), items_add=frozenset({'Garfield 2'}), confidence=0.2, lift=6.25)]),
#  RelationRecord(items=frozenset({'George of the Jungle', 'Last Man Standing'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Last Man Standing'}), items_add=frozenset({'George of the Jungle'}), confidence=0.2105263157894737, lift=6.578947368421053)]),
#  RelationRecord(items=frozenset({'George of the Jungle', 'Mystery Men'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Mystery Men'}), items_add=frozenset({'George of the Jungle'}), confidence=0.20833333333333334, lift=6.510416666666667)]),
#  RelationRecord(items=frozenset({'Hotel Transylvania 2', 'Gigli'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Gigli'}), items_add=frozenset({'Hotel Transylvania 2'}), confidence=0.2105263157894737, lift=6.015037593984962)]),
#  RelationRecord(items=frozenset({'Marmaduke', 'Godzilla Resurgence'}), support=0.007, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Marmaduke'}), items_add=frozenset({'Godzilla Resurgence'}), confidence=0.21875, lift=3.1249999999999996)]),
#  RelationRecord(items=frozenset({'Salt', 'Godzilla Resurgence'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Salt'}), items_add=frozenset({'Godzilla Resurgence'}), confidence=0.2105263157894737, lift=3.007518796992481)]),
#  RelationRecord(items=frozenset({'Scooby-Doo', 'Godzilla Resurgence'}), support=0.007, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Scooby-Doo'}), items_add=frozenset({'Godzilla Resurgence'}), confidence=0.24137931034482757, lift=3.448275862068965)]),
#  RelationRecord(items=frozenset({'Godzilla Resurgence', 'The Chronicles of Riddick'}), support=0.008, ordered_statistics=[OrderedStatistic(items_base=frozenset({'The Chronicles of Riddick'}), items_add=frozenset({'Godzilla Resurgence'}), confidence=0.22222222222222224, lift=3.1746031746031744)]),
#  RelationRecord(items=frozenset({'Godzilla Resurgence', 'The Secret Life of Pets'}), support=0.006, ordered_statistics=[OrderedStatistic(items_base=frozenset({'The Secret Life of Pets'}), items_add=frozenset({'Godzilla Resurgence'}), confidence=0.23076923076923078, lift=3.2967032967032965)]),
#  RelationRecord(items=frozenset({'Green Zone', 'I, Frankenstein'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'I, Frankenstein'}), items_add=frozenset({'Green Zone'}), confidence=0.22222222222222224, lift=6.734006734006734)]),
#  RelationRecord(items=frozenset({'The Other Guys', 'Hairspray'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'The Other Guys'}), items_add=frozenset({'Hairspray'}), confidence=0.2173913043478261, lift=5.302226935312832)]),
#  RelationRecord(items=frozenset({'The Thin Red Line', 'Hairspray'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'The Thin Red Line'}), items_add=frozenset({'Hairspray'}), confidence=0.22222222222222224, lift=5.420054200542006)]),
#  RelationRecord(items=frozenset({'The Avengers', 'Hannibal'}), support=0.007, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Hannibal'}), items_add=frozenset({'The Avengers'}), confidence=0.20588235294117646, lift=3.489531405782652)]),
#  RelationRecord(items=frozenset({'Road to Perdition', 'Hansel & Gretel: Witch Hunters'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Hansel & Gretel: Witch Hunters'}), items_add=frozenset({'Road to Perdition'}), confidence=0.2, lift=5.2631578947368425)]),
#  RelationRecord(items=frozenset({'Hansel & Gretel: Witch Hunters', 'The Brothers Grimm'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Hansel & Gretel: Witch Hunters'}), items_add=frozenset({'The Brothers Grimm'}), confidence=0.2, lift=5.2631578947368425)]),
#  RelationRecord(items=frozenset({'Hard Rain', 'Man of Steel'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Hard Rain'}), items_add=frozenset({'Man of Steel'}), confidence=0.2173913043478261, lift=7.763975155279503)]),
#  RelationRecord(items=frozenset({'The Long Kiss Goodnight', 'Harry Potter and the Order of the Phoenix'}), support=0.006, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Harry Potter and the Order of the Phoenix'}), items_add=frozenset({'The Long Kiss Goodnight'}), confidence=0.2, lift=5.2631578947368425)]),
#  RelationRecord(items=frozenset({"Harry Potter and the Sorcerer's Stone", 'The Spanish Prisoner'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'The Spanish Prisoner'}), items_add=frozenset({"Harry Potter and the Sorcerer's Stone"}), confidence=0.2, lift=6.25)]),
#  RelationRecord(items=frozenset({'Osmosis Jones', 'Hercules'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Osmosis Jones'}), items_add=frozenset({'Hercules'}), confidence=0.23809523809523808, lift=3.720238095238095)]),
#  RelationRecord(items=frozenset({'Speed Racer', 'Hercules'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Speed Racer'}), items_add=frozenset({'Hercules'}), confidence=0.2272727272727273, lift=3.5511363636363638)]),
#  RelationRecord(items=frozenset({'The Good Dinosaur', 'Hitch'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Hitch'}), items_add=frozenset({'The Good Dinosaur'}), confidence=0.2173913043478261, lift=5.720823798627003)]),
#  RelationRecord(items=frozenset({'Hollywood Homicide', 'Jupiter Ascending'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Jupiter Ascending'}), items_add=frozenset({'Hollywood Homicide'}), confidence=0.23809523809523808, lift=6.802721088435373)]),
#  RelationRecord(items=frozenset({'The League of Extraordinary Gentlemen', 'Holy Man'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'The League of Extraordinary Gentlemen'}), items_add=frozenset({'Holy Man'}), confidence=0.2173913043478261, lift=7.012622720897617)]),
#  RelationRecord(items=frozenset({'The Change-Up', 'How to Lose a Guy in 10 Days'}), support=0.006, ordered_statistics=[OrderedStatistic(items_base=frozenset({'How to Lose a Guy in 10 Days'}), items_add=frozenset({'The Change-Up'}), confidence=0.24, lift=7.741935483870967)]),
#  RelationRecord(items=frozenset({'Inspector Gadget', 'How to Train Your Dragon 2'}), support=0.006, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Inspector Gadget'}), items_add=frozenset({'How to Train Your Dragon 2'}), confidence=0.20689655172413793, lift=6.4655172413793105)]),
#  RelationRecord(items=frozenset({'I Am Legend', 'The SpongeBob Movie: Sponge Out of Water'}), support=0.006, ordered_statistics=[OrderedStatistic(items_base=frozenset({'I Am Legend'}), items_add=frozenset({'The SpongeBob Movie: Sponge Out of Water'}), confidence=0.20689655172413793, lift=4.2223786066150595)]),
#  RelationRecord(items=frozenset({'Snow White and the Huntsman', 'I, Frankenstein'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'I, Frankenstein'}), items_add=frozenset({'Snow White and the Huntsman'}), confidence=0.22222222222222224, lift=3.76647834274953)]),
#  RelationRecord(items=frozenset({'The Pacifier', 'I, Frankenstein'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'I, Frankenstein'}), items_add=frozenset({'The Pacifier'}), confidence=0.22222222222222224, lift=6.944444444444445)]),
#  RelationRecord(items=frozenset({'Jack the Giant Slayer', 'Ice Age: Dawn of the Dinosaurs'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Jack the Giant Slayer'}), items_add=frozenset({'Ice Age: Dawn of the Dinosaurs'}), confidence=0.23809523809523808, lift=6.613756613756614)]),
#  RelationRecord(items=frozenset({'The Fast and the Furious', 'Immortals'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Immortals'}), items_add=frozenset({'The Fast and the Furious'}), confidence=0.2173913043478261, lift=3.8819875776397517)]),
#  RelationRecord(items=frozenset({'The Island', 'In the Heart of the Sea'}), support=0.006, ordered_statistics=[OrderedStatistic(items_base=frozenset({'The Island'}), items_add=frozenset({'In the Heart of the Sea'}), confidence=0.25, lift=6.756756756756757)]),
#  RelationRecord(items=frozenset({'Master and Commander: The Far Side of the World', 'Independence Day'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Independence Day'}), items_add=frozenset({'Master and Commander: The Far Side of the World'}), confidence=0.2173913043478261, lift=5.875440658049355)]),
#  RelationRecord(items=frozenset({'Indiana Jones and the Kingdom of the Crystal Skull', 'U-571'}), support=0.007, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Indiana Jones and the Kingdom of the Crystal Skull'}), items_add=frozenset({'U-571'}), confidence=0.20588235294117646, lift=5.417956656346749)]),
#  RelationRecord(items=frozenset({'Inglourious Basterds', 'The Thin Red Line'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'The Thin Red Line'}), items_add=frozenset({'Inglourious Basterds'}), confidence=0.22222222222222224, lift=8.547008547008549)]),
#  RelationRecord(items=frozenset({'Inkheart', 'The American President'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Inkheart'}), items_add=frozenset({'The American President'}), confidence=0.2105263157894737, lift=6.015037593984962)]),
#  RelationRecord(items=frozenset({"The Huntsman: Winter's War", "It's Complicated"}), support=0.003, ordered_statistics=[OrderedStatistic(items_base=frozenset({"It's Complicated"}), items_add=frozenset({"The Huntsman: Winter's War"}), confidence=0.3, lift=9.67741935483871)]),
#  RelationRecord(items=frozenset({'The Relic', 'Jason Bourne'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'The Relic'}), items_add=frozenset({'Jason Bourne'}), confidence=0.20833333333333334, lift=5.08130081300813)]),
#  RelationRecord(items=frozenset({'Volcano', 'Jason Bourne'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Volcano'}), items_add=frozenset({'Jason Bourne'}), confidence=0.2173913043478261, lift=5.302226935312832)]),
#  RelationRecord(items=frozenset({'Rio', 'Jurassic Park'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Jurassic Park'}), items_add=frozenset({'Rio'}), confidence=0.2173913043478261, lift=6.793478260869565)]),
#  RelationRecord(items=frozenset({'The Horse Whisperer', 'Jurassic World'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'The Horse Whisperer'}), items_add=frozenset({'Jurassic World'}), confidence=0.2173913043478261, lift=8.051529790660226)]),
#  RelationRecord(items=frozenset({'Just Like Heaven', 'The Twilight Saga: Breaking Dawn - Part 2'}), support=0.006, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Just Like Heaven'}), items_add=frozenset({'The Twilight Saga: Breaking Dawn - Part 2'}), confidence=0.2, lift=3.5087719298245617)]),
#  RelationRecord(items=frozenset({'Kangaroo Jack', 'The Expendables'}), support=0.006, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Kangaroo Jack'}), items_add=frozenset({'The Expendables'}), confidence=0.21428571428571427, lift=7.653061224489796), OrderedStatistic(items_base=frozenset({'The Expendables'}), items_add=frozenset({'Kangaroo Jack'}), confidence=0.21428571428571427, lift=7.653061224489796)]),
#  RelationRecord(items=frozenset({'The Lord of the Rings: The Two Towers', 'Kill Bill: Vol. 2'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'The Lord of the Rings: The Two Towers'}), items_add=frozenset({'Kill Bill: Vol. 2'}), confidence=0.2, lift=4.651162790697675)]),
#  RelationRecord(items=frozenset({'Knowing', 'Monkeybone'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Monkeybone'}), items_add=frozenset({'Knowing'}), confidence=0.2173913043478261, lift=8.695652173913043)]),
#  RelationRecord(items=frozenset({'Kung Fu Panda 3', 'The Soloist'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Kung Fu Panda 3'}), items_add=frozenset({'The Soloist'}), confidence=0.2272727272727273, lift=7.575757575757577)]),
#  RelationRecord(items=frozenset({'Lady in the Water', 'Pan'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Lady in the Water'}), items_add=frozenset({'Pan'}), confidence=0.20833333333333334, lift=3.531073446327684)]),
#  RelationRecord(items=frozenset({'Last Man Standing', 'Men in Black 3'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Last Man Standing'}), items_add=frozenset({'Men in Black 3'}), confidence=0.2105263157894737, lift=6.379585326953748)]),
#  RelationRecord(items=frozenset({'Random Hearts', 'Last Man Standing'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Last Man Standing'}), items_add=frozenset({'Random Hearts'}), confidence=0.2105263157894737, lift=5.134788189987163)]),
#  RelationRecord(items=frozenset({'Lilo & Stitch', 'The Spanish Prisoner'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'The Spanish Prisoner'}), items_add=frozenset({'Lilo & Stitch'}), confidence=0.25, lift=7.352941176470588)]),
#  RelationRecord(items=frozenset({'Looney Tunes: Back in Action', 'Mercury Rising'}), support=0.006, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Looney Tunes: Back in Action'}), items_add=frozenset({'Mercury Rising'}), confidence=0.2857142857142857, lift=8.658008658008658)]),
#  RelationRecord(items=frozenset({'Lost in Space', 'The Green Hornet'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Lost in Space'}), items_add=frozenset({'The Green Hornet'}), confidence=0.2105263157894737, lift=6.791171477079796)]),
#  RelationRecord(items=frozenset({'Meet the Parents', 'Talladega Nights: The Ballad of Ricky Bobby'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Talladega Nights: The Ballad of Ricky Bobby'}), items_add=frozenset({'Meet the Parents'}), confidence=0.2173913043478261, lift=7.246376811594204)]),
#  RelationRecord(items=frozenset({'R.I.P.D.', 'Men in Black'}), support=0.006, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Men in Black'}), items_add=frozenset({'R.I.P.D.'}), confidence=0.2, lift=5.555555555555556)]),
#  RelationRecord(items=frozenset({'The Legend of Tarzan', 'Minions'}), support=0.006, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Minions'}), items_add=frozenset({'The Legend of Tarzan'}), confidence=0.22222222222222224, lift=4.1928721174004195)]),
#  RelationRecord(items=frozenset({'Minority Report', 'Supernova'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Minority Report'}), items_add=frozenset({'Supernova'}), confidence=0.2272727272727273, lift=5.543237250554324)]),
#  RelationRecord(items=frozenset({'Star Wars: Episode III - Revenge of the Sith', 'Miss Congeniality 2: Armed and Fabulous'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Miss Congeniality 2: Armed and Fabulous'}), items_add=frozenset({'Star Wars: Episode III - Revenge of the Sith'}), confidence=0.2, lift=4.166666666666667)]),
#  RelationRecord(items=frozenset({"The Huntsman: Winter's War", 'Miss Congeniality 2: Armed and Fabulous'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Miss Congeniality 2: Armed and Fabulous'}), items_add=frozenset({"The Huntsman: Winter's War"}), confidence=0.2, lift=6.451612903225807)]),
#  RelationRecord(items=frozenset({'The Long Kiss Goodnight', 'Miss Congeniality 2: Armed and Fabulous'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Miss Congeniality 2: Armed and Fabulous'}), items_add=frozenset({'The Long Kiss Goodnight'}), confidence=0.2, lift=5.2631578947368425)]),
#  RelationRecord(items=frozenset({'The Pink Panther', 'Miss Congeniality 2: Armed and Fabulous'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Miss Congeniality 2: Armed and Fabulous'}), items_add=frozenset({'The Pink Panther'}), confidence=0.2, lift=6.25)]),
#  RelationRecord(items=frozenset({'The Sentinel', 'Miss Congeniality 2: Armed and Fabulous'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Miss Congeniality 2: Armed and Fabulous'}), items_add=frozenset({'The Sentinel'}), confidence=0.2, lift=6.0606060606060606)]),
#  RelationRecord(items=frozenset({'Mission: Impossible', 'Total Recall'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Mission: Impossible'}), items_add=frozenset({'Total Recall'}), confidence=0.2, lift=3.5087719298245617)]),
#  RelationRecord(items=frozenset({'Mission: Impossible III', 'Resident Evil: Afterlife'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Resident Evil: Afterlife'}), items_add=frozenset({'Mission: Impossible III'}), confidence=0.20833333333333334, lift=6.313131313131313)]),
#  RelationRecord(items=frozenset({'Moneyball', 'Rush Hour 2'}), support=0.006, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Moneyball'}), items_add=frozenset({'Rush Hour 2'}), confidence=0.21428571428571427, lift=6.912442396313364)]),
#  RelationRecord(items=frozenset({'Monster House', 'Snow White and the Huntsman'}), support=0.006, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Monster House'}), items_add=frozenset({'Snow White and the Huntsman'}), confidence=0.20689655172413793, lift=3.506721215663355)]),
#  RelationRecord(items=frozenset({'Monsters, Inc.', 'X-Men: First Class'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Monsters, Inc.'}), items_add=frozenset({'X-Men: First Class'}), confidence=0.2272727272727273, lift=5.285412262156449)]),
#  RelationRecord(items=frozenset({'Mortdecai', 'Star Wars: Episode VII - The Force Awakens'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Mortdecai'}), items_add=frozenset({'Star Wars: Episode VII - The Force Awakens'}), confidence=0.23809523809523808, lift=6.435006435006435)]),
#  RelationRecord(items=frozenset({'Mr. Peabody & Sherman', 'The Aviator'}), support=0.006, ordered_statistics=[OrderedStatistic(items_base=frozenset({'The Aviator'}), items_add=frozenset({'Mr. Peabody & Sherman'}), confidence=0.20689655172413793, lift=6.269592476489028)]),
#  RelationRecord(items=frozenset({'Murder by Numbers', 'Real Steel'}), support=0.006, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Murder by Numbers'}), items_add=frozenset({'Real Steel'}), confidence=0.25, lift=7.352941176470588)]),
#  RelationRecord(items=frozenset({'The Legend of Tarzan', 'My Favorite Martian'}), support=0.006, ordered_statistics=[OrderedStatistic(items_base=frozenset({'My Favorite Martian'}), items_add=frozenset({'The Legend of Tarzan'}), confidence=0.24, lift=4.528301886792453)]),
#  RelationRecord(items=frozenset({'Random Hearts', 'Night at the Museum'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Night at the Museum'}), items_add=frozenset({'Random Hearts'}), confidence=0.20833333333333334, lift=5.08130081300813)]),
# ...
#  RelationRecord(items=frozenset({'DragonHeart', 'The Haunting', 'Insurgent'}), support=0.003, ordered_statistics=[OrderedStatistic(items_base=frozenset({'DragonHeart', 'Insurgent'}), items_add=frozenset({'The Haunting'}), confidence=0.75, lift=20.833333333333336), OrderedStatistic(items_base=frozenset({'DragonHeart', 'The Haunting'}), items_add=frozenset({'Insurgent'}), confidence=0.75, lift=25.0), OrderedStatistic(items_base=frozenset({'The Haunting', 'Insurgent'}), items_add=frozenset({'DragonHeart'}), confidence=0.75, lift=34.09090909090909)]),
#  RelationRecord(items=frozenset({'Prometheus', 'Lara Croft Tomb Raider: The Cradle of Life', 'Dreamcatcher'}), support=0.003, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Lara Croft Tomb Raider: The Cradle of Life', 'Dreamcatcher'}), items_add=frozenset({'Prometheus'}), confidence=0.75, lift=25.86206896551724), OrderedStatistic(items_base=frozenset({'Prometheus', 'Dreamcatcher'}), items_add=frozenset({'Lara Croft Tomb Raider: The Cradle of Life'}), confidence=0.75, lift=28.846153846153847), OrderedStatistic(items_base=frozenset({'Prometheus', 'Lara Croft Tomb Raider: The Cradle of Life'}), items_add=frozenset({'Dreamcatcher'}), confidence=0.75, lift=23.4375)]),
#  RelationRecord(items=frozenset({'Dreamgirls', 'Sky Captain and the World of Tomorrow', 'RED'}), support=0.003, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Dreamgirls', 'RED'}), items_add=frozenset({'Sky Captain and the World of Tomorrow'}), confidence=1.0, lift=24.390243902439025), OrderedStatistic(items_base=frozenset({'Dreamgirls', 'Sky Captain and the World of Tomorrow'}), items_add=frozenset({'RED'}), confidence=0.75, lift=34.09090909090909), OrderedStatistic(items_base=frozenset({'Sky Captain and the World of Tomorrow', 'RED'}), items_add=frozenset({'Dreamgirls'}), confidence=1.0, lift=33.333333333333336)]),
#  RelationRecord(items=frozenset({'Happy Feet 2', 'Dredd', 'Silent Hill'}), support=0.003, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Happy Feet 2', 'Dredd'}), items_add=frozenset({'Silent Hill'}), confidence=0.75, lift=22.058823529411764), OrderedStatistic(items_base=frozenset({'Dredd', 'Silent Hill'}), items_add=frozenset({'Happy Feet 2'}), confidence=1.0, lift=24.390243902439025), OrderedStatistic(items_base=frozenset({'Happy Feet 2', 'Silent Hill'}), items_add=frozenset({'Dredd'}), confidence=0.75, lift=26.785714285714285)]),
#  RelationRecord(items=frozenset({'Spanglish', 'Where the Wild Things Are', 'Déjà Vu'}), support=0.003, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Spanglish', 'Déjà Vu'}), items_add=frozenset({'Where the Wild Things Are'}), confidence=0.75, lift=35.714285714285715), OrderedStatistic(items_base=frozenset({'Where the Wild Things Are', 'Déjà Vu'}), items_add=frozenset({'Spanglish'}), confidence=1.0, lift=24.390243902439025), OrderedStatistic(items_base=frozenset({'Spanglish', 'Where the Wild Things Are'}), items_add=frozenset({'Déjà Vu'}), confidence=0.6, lift=18.18181818181818)]),
#  RelationRecord(items=frozenset({'Pompeii', 'Thunderbirds', 'Eat Pray Love'}), support=0.003, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Pompeii', 'Eat Pray Love'}), items_add=frozenset({'Thunderbirds'}), confidence=1.0, lift=43.47826086956522), OrderedStatistic(items_base=frozenset({'Thunderbirds', 'Eat Pray Love'}), items_add=frozenset({'Pompeii'}), confidence=1.0, lift=32.25806451612903), OrderedStatistic(items_base=frozenset({'Pompeii', 'Thunderbirds'}), items_add=frozenset({'Eat Pray Love'}), confidence=1.0, lift=29.41176470588235)]),
#  RelationRecord(items=frozenset({'Grown Ups', 'The Fifth Element', 'Edge of Darkness'}), support=0.003, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Grown Ups', 'Edge of Darkness'}), items_add=frozenset({'The Fifth Element'}), confidence=1.0, lift=30.3030303030303), OrderedStatistic(items_base=frozenset({'The Fifth Element', 'Edge of Darkness'}), items_add=frozenset({'Grown Ups'}), confidence=1.0, lift=26.315789473684212), OrderedStatistic(items_base=frozenset({'The Fifth Element', 'Grown Ups'}), items_add=frozenset({'Edge of Darkness'}), confidence=1.0, lift=37.03703703703704)]),
#  RelationRecord(items=frozenset({'The Postman', 'Jack Reacher', 'Edtv'}), support=0.003, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Jack Reacher', 'Edtv'}), items_add=frozenset({'The Postman'}), confidence=1.0, lift=37.03703703703704), OrderedStatistic(items_base=frozenset({'The Postman', 'Edtv'}), items_add=frozenset({'Jack Reacher'}), confidence=1.0, lift=33.333333333333336), OrderedStatistic(items_base=frozenset({'The Postman', 'Jack Reacher'}), items_add=frozenset({'Edtv'}), confidence=0.75, lift=35.714285714285715)]),
#  RelationRecord(items=frozenset({'Elektra', 'Flightplan', 'Leatherheads'}), support=0.003, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Elektra', 'Flightplan'}), items_add=frozenset({'Leatherheads'}), confidence=0.6, lift=18.18181818181818), OrderedStatistic(items_base=frozenset({'Elektra', 'Leatherheads'}), items_add=frozenset({'Flightplan'}), confidence=1.0, lift=33.333333333333336), OrderedStatistic(items_base=frozenset({'Flightplan', 'Leatherheads'}), items_add=frozenset({'Elektra'}), confidence=1.0, lift=35.714285714285715)]),
#  RelationRecord(items=frozenset({'Elizabethtown', 'The Day the Earth Stood Still', 'World War Z'}), support=0.003, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Elizabethtown', 'The Day the Earth Stood Still'}), items_add=frozenset({'World War Z'}), confidence=1.0, lift=32.25806451612903), OrderedStatistic(items_base=frozenset({'Elizabethtown', 'World War Z'}), items_add=frozenset({'The Day the Earth Stood Still'}), confidence=1.0, lift=32.25806451612903), OrderedStatistic(items_base=frozenset({'The Day the Earth Stood Still', 'World War Z'}), items_add=frozenset({'Elizabethtown'}), confidence=0.75, lift=22.058823529411764)]),
#  RelationRecord(items=frozenset({'Godzilla Resurgence', 'Elysium', 'The Fast and the Furious'}), support=0.003, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Godzilla Resurgence', 'Elysium'}), items_add=frozenset({'The Fast and the Furious'}), confidence=0.6, lift=10.714285714285714), OrderedStatistic(items_base=frozenset({'Elysium', 'The Fast and the Furious'}), items_add=frozenset({'Godzilla Resurgence'}), confidence=0.75, lift=10.714285714285714), OrderedStatistic(items_base=frozenset({'Godzilla Resurgence', 'The Fast and the Furious'}), items_add=frozenset({'Elysium'}), confidence=0.75, lift=23.4375)]),
#  RelationRecord(items=frozenset({'The Simpsons Movie', 'Enchanted', 'The Adjustment Bureau'}), support=0.003, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Enchanted', 'The Adjustment Bureau'}), items_add=frozenset({'The Simpsons Movie'}), confidence=1.0, lift=26.315789473684212), OrderedStatistic(items_base=frozenset({'Enchanted', 'The Simpsons Movie'}), items_add=frozenset({'The Adjustment Bureau'}), confidence=0.75, lift=24.193548387096776), OrderedStatistic(items_base=frozenset({'The Simpsons Movie', 'The Adjustment Bureau'}), items_add=frozenset({'Enchanted'}), confidence=0.5, lift=17.857142857142858)]),
#  RelationRecord(items=frozenset({'Sphere', "Hart's War", 'Enemy at the Gates'}), support=0.003, ordered_statistics=[OrderedStatistic(items_base=frozenset({"Hart's War", 'Enemy at the Gates'}), items_add=frozenset({'Sphere'}), confidence=0.75, lift=25.0), OrderedStatistic(items_base=frozenset({'Sphere', 'Enemy at the Gates'}), items_add=frozenset({"Hart's War"}), confidence=1.0, lift=37.03703703703704), OrderedStatistic(items_base=frozenset({'Sphere', "Hart's War"}), items_add=frozenset({'Enemy at the Gates'}), confidence=1.0, lift=30.3030303030303)]),
#  RelationRecord(items=frozenset({'Lucky Numbers', 'Enemy at the Gates', 'Transcendence'}), support=0.003, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Lucky Numbers', 'Enemy at the Gates'}), items_add=frozenset({'Transcendence'}), confidence=0.75, lift=25.0), OrderedStatistic(items_base=frozenset({'Enemy at the Gates', 'Transcendence'}), items_add=frozenset({'Lucky Numbers'}), confidence=0.75, lift=26.785714285714285), OrderedStatistic(items_base=frozenset({'Lucky Numbers', 'Transcendence'}), items_add=frozenset({'Enemy at the Gates'}), confidence=0.75, lift=22.727272727272727)]),
#  RelationRecord(items=frozenset({'Shrek', 'Enemy of the State', 'Road to Perdition'}), support=0.003, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Enemy of the State', 'Road to Perdition'}), items_add=frozenset({'Shrek'}), confidence=0.75, lift=16.666666666666668), OrderedStatistic(items_base=frozenset({'Shrek', 'Enemy of the State'}), items_add=frozenset({'Road to Perdition'}), confidence=0.75, lift=19.736842105263158), OrderedStatistic(items_base=frozenset({'Shrek', 'Road to Perdition'}), items_add=frozenset({'Enemy of the State'}), confidence=0.75, lift=22.058823529411764)]),
#  RelationRecord(items=frozenset({'The Lord of the Rings: The Return of the King', 'Epic', 'Paddington'}), support=0.003, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Epic', 'Paddington'}), items_add=frozenset({'The Lord of the Rings: The Return of the King'}), confidence=1.0, lift=28.57142857142857), OrderedStatistic(items_base=frozenset({'The Lord of the Rings: The Return of the King', 'Epic'}), items_add=frozenset({'Paddington'}), confidence=0.75, lift=25.0), OrderedStatistic(items_base=frozenset({'The Lord of the Rings: The Return of the King', 'Paddington'}), items_add=frozenset({'Epic'}), confidence=0.6, lift=19.35483870967742)]),
#  RelationRecord(items=frozenset({'The Ridiculous 6', 'Pan', 'Eragon'}), support=0.003, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Pan', 'Eragon'}), items_add=frozenset({'The Ridiculous 6'}), confidence=0.75, lift=26.785714285714285), OrderedStatistic(items_base=frozenset({'The Ridiculous 6', 'Eragon'}), items_add=frozenset({'Pan'}), confidence=0.75, lift=12.711864406779661), OrderedStatistic(items_base=frozenset({'The Ridiculous 6', 'Pan'}), items_add=frozenset({'Eragon'}), confidence=1.0, lift=38.46153846153846)]),
#  RelationRecord(items=frozenset({'Indiana Jones and the Kingdom of the Crystal Skull', 'Eraser', 'The Last Castle'}), support=0.003, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Indiana Jones and the Kingdom of the Crystal Skull', 'Eraser'}), items_add=frozenset({'The Last Castle'}), confidence=0.75, lift=25.0), OrderedStatistic(items_base=frozenset({'The Last Castle', 'Eraser'}), items_add=frozenset({'Indiana Jones and the Kingdom of the Crystal Skull'}), confidence=0.75, lift=22.058823529411764), OrderedStatistic(items_base=frozenset({'Indiana Jones and the Kingdom of the Crystal Skull', 'The Last Castle'}), items_add=frozenset({'Eraser'}), confidence=1.0, lift=35.714285714285715)]),
#  RelationRecord(items=frozenset({'Eraser', 'Snow White and the Huntsman', 'The Avengers'}), support=0.003, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Eraser', 'Snow White and the Huntsman'}), items_add=frozenset({'The Avengers'}), confidence=0.75, lift=12.711864406779661), OrderedStatistic(items_base=frozenset({'Eraser', 'The Avengers'}), items_add=frozenset({'Snow White and the Huntsman'}), confidence=0.75, lift=12.711864406779661), OrderedStatistic(items_base=frozenset({'The Avengers', 'Snow White and the Huntsman'}), items_add=frozenset({'Eraser'}), confidence=0.5, lift=17.857142857142858)]),
#  RelationRecord(items=frozenset({'Space Cowboys', 'First Knight', 'Escape Plan'}), support=0.003, ordered_statistics=[OrderedStatistic(items_base=frozenset({'First Knight', 'Escape Plan'}), items_add=frozenset({'Space Cowboys'}), confidence=0.75, lift=25.0), OrderedStatistic(items_base=frozenset({'Space Cowboys', 'Escape Plan'}), items_add=frozenset({'First Knight'}), confidence=1.0, lift=41.666666666666664), OrderedStatistic(items_base=frozenset({'Space Cowboys', 'First Knight'}), items_add=frozenset({'Escape Plan'}), confidence=0.6, lift=20.68965517241379)]),
#  RelationRecord(items=frozenset({'Monster House', 'Snow White and the Huntsman', 'Escape Plan'}), support=0.003, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Monster House', 'Escape Plan'}), items_add=frozenset({'Snow White and the Huntsman'}), confidence=1.0, lift=16.949152542372882), OrderedStatistic(items_base=frozenset({'Snow White and the Huntsman', 'Escape Plan'}), items_add=frozenset({'Monster House'}), confidence=1.0, lift=34.48275862068965), OrderedStatistic(items_base=frozenset({'Monster House', 'Snow White and the Huntsman'}), items_add=frozenset({'Escape Plan'}), confidence=0.5, lift=17.241379310344826)]),
#  RelationRecord(items=frozenset({'Twister', 'Escape Plan', 'The Simpsons Movie'}), support=0.003, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Escape Plan', 'The Simpsons Movie'}), items_add=frozenset({'Twister'}), confidence=0.5, lift=16.129032258064516), OrderedStatistic(items_base=frozenset({'Escape Plan', 'Twister'}), items_add=frozenset({'The Simpsons Movie'}), confidence=0.75, lift=19.736842105263158), OrderedStatistic(items_base=frozenset({'Twister', 'The Simpsons Movie'}), items_add=frozenset({'Escape Plan'}), confidence=1.0, lift=34.48275862068965)]),
#  RelationRecord(items=frozenset({'Evan Almighty', 'Supernova', 'Forrest Gump'}), support=0.003, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Evan Almighty', 'Forrest Gump'}), items_add=frozenset({'Supernova'}), confidence=0.6, lift=14.634146341463413), OrderedStatistic(items_base=frozenset({'Evan Almighty', 'Supernova'}), items_add=frozenset({'Forrest Gump'}), confidence=0.6, lift=16.666666666666668), OrderedStatistic(items_base=frozenset({'Supernova', 'Forrest Gump'}), items_add=frozenset({'Evan Almighty'}), confidence=0.6, lift=20.0)]),
#  RelationRecord(items=frozenset({'Lara Croft Tomb Raider: The Cradle of Life', 'Unbroken', 'Event Horizon'}), support=0.003, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Lara Croft Tomb Raider: The Cradle of Life', 'Event Horizon'}), items_add=frozenset({'Unbroken'}), confidence=0.75, lift=28.846153846153847), OrderedStatistic(items_base=frozenset({'Unbroken', 'Event Horizon'}), items_add=frozenset({'Lara Croft Tomb Raider: The Cradle of Life'}), confidence=0.75, lift=28.846153846153847), OrderedStatistic(items_base=frozenset({'Unbroken', 'Lara Croft Tomb Raider: The Cradle of Life'}), items_add=frozenset({'Event Horizon'}), confidence=0.6, lift=16.666666666666668)]),
#  RelationRecord(items=frozenset({'Terminator 2: Judgment Day', 'Just Like Heaven', 'Everest'}), support=0.003, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Just Like Heaven', 'Everest'}), items_add=frozenset({'Terminator 2: Judgment Day'}), confidence=0.6, lift=15.384615384615383), OrderedStatistic(items_base=frozenset({'Terminator 2: Judgment Day', 'Everest'}), items_add=frozenset({'Just Like Heaven'}), confidence=0.75, lift=25.0), OrderedStatistic(items_base=frozenset({'Terminator 2: Judgment Day', 'Just Like Heaven'}), items_add=frozenset({'Everest'}), confidence=1.0, lift=23.809523809523807)]),
#  RelationRecord(items=frozenset({'Unbroken', 'Harry Potter and the Deathly Hallows: Part I', 'Executive Decision'}), support=0.003, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Harry Potter and the Deathly Hallows: Part I', 'Executive Decision'}), items_add=frozenset({'Unbroken'}), confidence=0.75, lift=28.846153846153847), OrderedStatistic(items_base=frozenset({'Unbroken', 'Executive Decision'}), items_add=frozenset({'Harry Potter and the Deathly Hallows: Part I'}), confidence=0.75, lift=19.23076923076923), OrderedStatistic(items_base=frozenset({'Unbroken', 'Harry Potter and the Deathly Hallows: Part I'}), items_add=frozenset({'Executive Decision'}), confidence=0.6, lift=15.0)]),
#  ...]

# %% [markdown]
# ## Visualization of Results

# %%
movie,r1,support=[],[],[]
for result in results:
    movie.append(tuple(result[2][0][0])[0])
    r1.append(tuple(result[2][0][1])[0])
    support.append(result[1])

# %%
columns=list(zip(movie,r1,support))

# %% [markdown]
# Converting into dataframe

# %%
result_df=pd.DataFrame(columns)
result_df.columns=['Film yang dipilih','Rekomendasi','Support']
result_df
# Out:
#                               Film yang dipilih  ... Support
# 0                                      13 Hours  ...   0.006
# 1                                      S.W.A.T.  ...   0.005
# 2                                        2 Guns  ...   0.007
# 3                                      Catwoman  ...   0.006
# 4                                          Salt  ...   0.004
# ...                                         ...  ...     ...
# 1164                       The Legend of Tarzan  ...   0.003
# 1165      The Lord of the Rings: The Two Towers  ...   0.003
# 1166                             This Means War  ...   0.003
# 1167                                      Turbo  ...   0.003
# 1168  The Twilight Saga: Breaking Dawn - Part 2  ...   0.003
#
# [1169 rows x 3 columns]

# %% [markdown]
# Diurutkan berdasarkan "Support"

# %%
result_df=result_df.sort_values('Support',ascending=False)
result_df
# Out:
#                                  Film yang dipilih  ... Support
# 26                                          Avatar  ...   0.047
# 23                                    Man of Steel  ...   0.028
# 25    Star Wars: Episode II - Attack of the Clones  ...   0.028
# 22                                     End of Days  ...   0.025
# 28           The League of Extraordinary Gentlemen  ...   0.023
# ...                                            ...  ...     ...
# 552                           Hotel Transylvania 2  ...   0.003
# 553                           Hotel Transylvania 2  ...   0.003
# 554                           Hotel Transylvania 2  ...   0.003
# 555                 How the Grinch Stole Christmas  ...   0.003
# 1168     The Twilight Saga: Breaking Dawn - Part 2  ...   0.003
#
# [1169 rows x 3 columns]
